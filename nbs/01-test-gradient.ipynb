# %% [markdown]
# #### Test: Gradient image

# %%
import numpy as np
from PIL import Image

# Create a gradient image
gradient = np.linspace(0, 255, 500).astype(np.uint8)
gradient = np.tile(gradient, (500, 1))
Image.fromarray(gradient).save('test_gradient.png')

# Display it to verify
Image.open('test_gradient.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=500x500>

# %%
# !python src/main.py --input test_gradient.png --output test_output.png --no-quote
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/Resources/Python.app/Contents/MacOS/Python: can't open file '/Users/telasi/Developer/TMC/nbs/src/main.py': [Errno 2] No such file or directory

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load both images
original = Image.open('test_gradient.png')
processed = Image.open('test_output.png')

# Display side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
ax1.imshow(original, cmap='gray')
ax1.set_title('Original Gradient')
ax1.axis('off')

ax2.imshow(processed, cmap='gray')
ax2.set_title('Processed Output')
ax2.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 # Load both images
#       5 original = Image.open('test_gradient.png')
# ----> 6 processed = Image.open('test_output.png')
#       8 # Display side by side
#       9 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
#
# File ~/Developer/TMC/venv/lib/python3.14/site-packages/PIL/Image.py:3512, in open(fp, mode, formats)
#    3510 if is_path(fp):
#    3511     filename = os.fspath(fp)
# -> 3512     fp = builtins.open(filename, "rb")
#    3513     exclusive_fp = True
#    3514 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_output.png'
